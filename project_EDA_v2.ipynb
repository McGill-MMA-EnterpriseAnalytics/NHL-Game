# %% [markdown]
# # EDA
# Files:
# - A pre-merged dataset containing statistics for period 1 game that includes:
#     - game.csv
#     - game_teams_stats.csv
#     - game_plays.csv
#
# - game_skater_stats.csv
# - game_goalie_stats.csv
# - player_info.csv

# %%
import pandas as pd
import numpy as np
import copy
import math

pd.set_option('display.max_columns', None)

# %%
data_path = 'nhl_data/'

# %%
games = pd.read_csv(data_path+'game.csv')
print(games.shape)
games.head()
# Out:
# (26305, 15)
#       game_id    season type         date_time_GMT  away_team_id  \
# 0  2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1  2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2  2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3  2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4  2017020586  20172018    R  2017-12-30T03:00:00Z            20
#
#    home_team_id  away_goals  home_goals       outcome home_rink_side_start  \
# 0            16           4           7  home win REG                right
# 1             7           4           3   away win OT                 left
# 2            52           4           1  away win REG                right
# 3            12           1           2  home win REG                right
# 4            24           1           2  home win REG                 left
#
#             venue           venue_link   venue_time_zone_id  \
# 0   United Center  /api/v1/venues/null      America/Chicago
# 1  KeyBank Center  /api/v1/venues/null     America/New_York
# 2      MTS Centre  /api/v1/venues/null     America/Winnipeg
# 3       PNC Arena  /api/v1/venues/null     America/New_York
# 4    Honda Center  /api/v1/venues/null  America/Los_Angeles
#
#    venue_time_zone_offset venue_time_zone_tz
# 0                      -5                CDT
# 1                      -4                EDT
# 2                      -5                CDT
# 3                      -4                EDT
# 4                      -7                PDT

# %%
game_stats = pd.read_csv(data_path+'game_teams_stats.csv')
print(game_stats.shape)
game_stats.head()
# Out:
# (52610, 17)
#       game_id  team_id   HoA    won settled_in        head_coach  goals  \
# 0  2016020045        4  away  False        REG      Dave Hakstol    4.0
# 1  2016020045       16  home   True        REG  Joel Quenneville    7.0
# 2  2017020812       24  away   True         OT     Randy Carlyle    4.0
# 3  2017020812        7  home  False         OT      Phil Housley    3.0
# 4  2015020314       21  away   True        REG       Patrick Roy    4.0
#
#    shots  hits  pim  powerPlayOpportunities  powerPlayGoals  \
# 0   27.0  30.0  6.0                     4.0             2.0
# 1   28.0  20.0  8.0                     3.0             2.0
# 2   34.0  16.0  6.0                     3.0             1.0
# 3   33.0  17.0  8.0                     2.0             1.0
# 4   29.0  17.0  9.0                     3.0             1.0
#
#    faceOffWinPercentage  giveaways  takeaways  blocked startRinkSide
# 0                  50.9       12.0        9.0     11.0          left
# 1                  49.1       16.0        8.0      9.0          left
# 2                  43.8        7.0        4.0     14.0         right
# 3                  56.2        5.0        6.0     14.0         right
# 4                  45.7       13.0        5.0     20.0          left

# %%
game_skater_stats = pd.read_csv(data_path+'game_skater_stats.csv')
print(game_skater_stats.shape)
game_skater_stats.head()
# Out:
# (945830, 22)
#       game_id  player_id  team_id  timeOnIce  assists  goals  shots  hits  \
# 0  2016020045    8468513        4        955        1      0      0   2.0
# 1  2016020045    8476906        4       1396        1      0      4   2.0
# 2  2016020045    8474668        4        915        0      0      1   1.0
# 3  2016020045    8473512        4       1367        3      0      0   0.0
# 4  2016020045    8471762        4        676        0      0      3   2.0
#
#    powerPlayGoals  powerPlayAssists  penaltyMinutes  faceOffWins  \
# 0               0                 0               0            0
# 1               0                 0               2            0
# 2               0                 0               0            0
# 3               0                 2               0           11
# 4               0                 0               0            0
#
#    faceoffTaken  takeaways  giveaways  shortHandedGoals  shortHandedAssists  \
# 0             0        1.0        1.0                 0                   0
# 1             0        1.0        2.0                 0                   0
# 2             0        2.0        0.0                 0                   0
# 3            27        0.0        0.0                 0                   0
# 4             0        0.0        1.0                 0                   0
#
#    blocked  plusMinus  evenTimeOnIce  shortHandedTimeOnIce  powerPlayTimeOnIce
# 0      1.0          1            858                    97                   0
# 1      2.0          0           1177                     0                 219
# 2      0.0         -1            805                     0                 110
# 3      0.0         -1           1083                    19                 265
# 4      0.0         -1            613                    63                   0

# %%
game_goalie_stats = pd.read_csv(data_path+'game_goalie_stats.csv')
print(game_goalie_stats.shape)
game_goalie_stats.head()
# Out:
# (56656, 19)
#       game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 0  2016020045    8473607        4       1504        0      0    0     16
# 1  2016020045    8473461        4       2011        0      0    0     11
# 2  2016020045    8470645       16       3598        0      0    0     27
# 3  2017020812    8468011       24       3696        0      0    0     33
# 4  2017020812    8475215        7       3539        0      0    0     33
#
#    saves  powerPlaySaves  shortHandedSaves  evenSaves  \
# 0     12               1                 0         11
# 1      9               1                 0          8
# 2     23               2                 0         21
# 3     30               1                 2         27
# 4     29               4                 1         24
#
#    shortHandedShotsAgainst  evenShotsAgainst  powerPlayShotsAgainst decision  \
# 0                        0                13                      3      NaN
# 1                        0                10                      1        L
# 2                        0                23                      4        W
# 3                        3                28                      2        W
# 4                        1                27                      5        L
#
#    savePercentage  powerPlaySavePercentage  evenStrengthSavePercentage
# 0       75.000000                33.333333                   84.615385
# 1       81.818182               100.000000                   80.000000
# 2       85.185185                50.000000                   91.304348
# 3       90.909091                50.000000                   96.428571
# 4       87.878788                80.000000                   88.888889

# %%
game_player = pd.read_csv(data_path+'player_info.csv')
print(game_player.shape)
game_player.head()
# Out:
# (3925, 12)
#    player_id firstName      lastName nationality       birthCity  \
# 0    8466148    Marian         Hossa         SVK   Stará Lubovna
# 1    8465058    Michal      Rozsival         CZE          Vlasim
# 2    8476906    Shayne  Gostisbehere         USA  Pembroke Pines
# 3    8466285     Brian      Campbell         CAN       Strathroy
# 4    8470607     Brent      Seabrook         CAN        Richmond
#
#   primaryPosition            birthDate birthStateProvince  height  height_cm  \
# 0              RW  1979-01-12 00:00:00                NaN   6' 1"     185.42
# 1               D  1978-09-03 01:00:00                NaN   6' 1"     185.42
# 2               D  1993-04-20 01:00:00                 FL  5' 11"     180.34
# 3               D  1979-05-23 01:00:00                 ON  5' 10"     177.80
# 4               D  1985-04-20 01:00:00                 BC   6' 3"     190.50
#
#    weight shootsCatches
# 0   207.0             L
# 1   210.0             R
# 2   180.0             L
# 3   192.0             L
# 4   220.0             R

# %% [markdown]
# ## Merge other data
# - drop duplicates
# - append columns to the 'Period_1_Game_Stats.csv'

# %% [markdown]
# ### Merge game_skater_stats and period 1 data

# %%
period1 = pd.read_csv(data_path+'Period_1_Game_Stats.csv')
print(period1.columns)
period1 = period1.drop(columns = ['goals', 'shots', 'hits', 'giveaways', 'takeaways', 'blocked'])
period1.head()
# Out:
# Index(['game_id', 'team_id_for', 'HoA', 'won', 'settled_in', 'head_coach',
#        'goals', 'shots', 'hits', 'pim', 'powerPlayOpportunities',
#        'powerPlayGoals', 'faceOffWinPercentage', 'giveaways', 'takeaways',
#        'blocked', 'startRinkSide', 'Shots', 'Goals', 'Takeaways', 'Hits',
#        'Blocked Shots', 'Giveaways', 'Missed Shots', 'Penalities',
#        '#Won Faceoffs'],
#       dtype='object')
#       game_id  team_id_for   HoA    won settled_in        head_coach  pim  \
# 0  2016020045            4  away  False        REG      Dave Hakstol  6.0
# 1  2016020045           16  home   True        REG  Joel Quenneville  8.0
# 2  2017020812           24  away   True         OT     Randy Carlyle  6.0
# 3  2017020812            7  home  False         OT      Phil Housley  8.0
# 4  2015020314           21  away   True        REG       Patrick Roy  9.0
#
#    powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage startRinkSide  \
# 0                     4.0             2.0                  50.9          left
# 1                     3.0             2.0                  49.1          left
# 2                     3.0             1.0                  43.8         right
# 3                     2.0             1.0                  56.2         right
# 4                     3.0             1.0                  45.7          left
#
#    Shots  Goals  Takeaways  Hits  Blocked Shots  Giveaways  Missed Shots  \
# 0    8.0    0.0        1.0  14.0            3.0        6.0           4.0
# 1    8.0    3.0        3.0   5.0            3.0        7.0           0.0
# 2   11.0    0.0        0.0   4.0            6.0        2.0           6.0
# 3   12.0    1.0        2.0   4.0            8.0        0.0           3.0
# 4    9.0    0.0        3.0   4.0            7.0        7.0           3.0
#
#    Penalities  #Won Faceoffs
# 0         1.0           10.0
# 1         1.0           12.0
# 2         1.0           11.0
# 3         3.0            9.0
# 4         2.0            7.0

# %%
game_skater_stats = game_skater_stats.drop_duplicates()
print(game_skater_stats.columns)
game_skater_stats.head()
# selected columns: timeOnIce, evenTimeOnIce, shortHandedTimeOnIce, powerPlayTimeOnIce
# Out:
# Index(['game_id', 'player_id', 'team_id', 'timeOnIce', 'assists', 'goals',
#        'shots', 'hits', 'powerPlayGoals', 'powerPlayAssists', 'penaltyMinutes',
#        'faceOffWins', 'faceoffTaken', 'takeaways', 'giveaways',
#        'shortHandedGoals', 'shortHandedAssists', 'blocked', 'plusMinus',
#        'evenTimeOnIce', 'shortHandedTimeOnIce', 'powerPlayTimeOnIce'],
#       dtype='object')
#       game_id  player_id  team_id  timeOnIce  assists  goals  shots  hits  \
# 0  2016020045    8468513        4        955        1      0      0   2.0
# 1  2016020045    8476906        4       1396        1      0      4   2.0
# 2  2016020045    8474668        4        915        0      0      1   1.0
# 3  2016020045    8473512        4       1367        3      0      0   0.0
# 4  2016020045    8471762        4        676        0      0      3   2.0
#
#    powerPlayGoals  powerPlayAssists  penaltyMinutes  faceOffWins  \
# 0               0                 0               0            0
# 1               0                 0               2            0
# 2               0                 0               0            0
# 3               0                 2               0           11
# 4               0                 0               0            0
#
#    faceoffTaken  takeaways  giveaways  shortHandedGoals  shortHandedAssists  \
# 0             0        1.0        1.0                 0                   0
# 1             0        1.0        2.0                 0                   0
# 2             0        2.0        0.0                 0                   0
# 3            27        0.0        0.0                 0                   0
# 4             0        0.0        1.0                 0                   0
#
#    blocked  plusMinus  evenTimeOnIce  shortHandedTimeOnIce  powerPlayTimeOnIce
# 0      1.0          1            858                    97                   0
# 1      2.0          0           1177                     0                 219
# 2      0.0         -1            805                     0                 110
# 3      0.0         -1           1083                    19                 265
# 4      0.0         -1            613                    63                   0

# %%
skater_agg_cols = game_skater_stats.groupby(['game_id', 'team_id'], as_index=False)[['timeOnIce', 'evenTimeOnIce', 'shortHandedTimeOnIce', 'powerPlayTimeOnIce']].mean()
skater_agg_cols.head()
# Out:
#       game_id  team_id    timeOnIce  evenTimeOnIce  shortHandedTimeOnIce  \
# 0  2000020001       21  1013.944444     583.611111            169.722222
# 1  2000020001       25   999.222222     582.944444            205.888889
# 2  2000020002        6  1029.388889     687.111111            116.055556
# 3  2000020002        9  1008.500000     685.333333            178.722222
# 4  2000020003        7   951.000000     667.555556            166.833333
#
#    powerPlayTimeOnIce
# 0          260.611111
# 1          210.388889
# 2          226.222222
# 3          144.444444
# 4          116.611111

# %%
combined = period1.merge(skater_agg_cols, how='left', left_on=['game_id', 'team_id_for'], right_on=['game_id', 'team_id'])
combined = combined.drop(columns = ['team_id_for'])
print(combined.shape)
combined.head()
# Out:
# (52610, 24)
#       game_id   HoA    won settled_in        head_coach  pim  \
# 0  2016020045  away  False        REG      Dave Hakstol  6.0
# 1  2016020045  home   True        REG  Joel Quenneville  8.0
# 2  2017020812  away   True         OT     Randy Carlyle  6.0
# 3  2017020812  home  False         OT      Phil Housley  8.0
# 4  2015020314  away   True        REG       Patrick Roy  9.0
#
#    powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage startRinkSide  \
# 0                     4.0             2.0                  50.9          left
# 1                     3.0             2.0                  49.1          left
# 2                     3.0             1.0                  43.8         right
# 3                     2.0             1.0                  56.2         right
# 4                     3.0             1.0                  45.7          left
#
#    Shots  Goals  Takeaways  Hits  Blocked Shots  Giveaways  Missed Shots  \
# 0    8.0    0.0        1.0  14.0            3.0        6.0           4.0
# 1    8.0    3.0        3.0   5.0            3.0        7.0           0.0
# 2   11.0    0.0        0.0   4.0            6.0        2.0           6.0
# 3   12.0    1.0        2.0   4.0            8.0        0.0           3.0
# 4    9.0    0.0        3.0   4.0            7.0        7.0           3.0
#
#    Penalities  #Won Faceoffs  team_id    timeOnIce  evenTimeOnIce  \
# 0         1.0           10.0      4.0   990.833333     841.388889
# 1         1.0           12.0     16.0   981.333333     836.777778
# 2         1.0           11.0     24.0  1002.222222     879.611111
# 3         3.0            9.0      7.0   999.222222     888.333333
# 4         2.0            7.0     21.0   986.666667     844.722222
#
#    shortHandedTimeOnIce  powerPlayTimeOnIce
# 0             55.555556           93.888889
# 1             75.111111           69.444444
# 2             28.444444           94.166667
# 3             75.333333           35.555556
# 4             53.333333           88.611111

# %%
combined.columns
# Out:
# Index(['game_id', 'HoA', 'won', 'settled_in', 'head_coach', 'pim',
#        'powerPlayOpportunities', 'powerPlayGoals', 'faceOffWinPercentage',
#        'startRinkSide', 'Shots', 'Goals', 'Takeaways', 'Hits', 'Blocked Shots',
#        'Giveaways', 'Missed Shots', 'Penalities', '#Won Faceoffs', 'team_id',
#        'timeOnIce', 'evenTimeOnIce', 'shortHandedTimeOnIce',
#        'powerPlayTimeOnIce'],
#       dtype='object')

# %% [markdown]
# ### Merge game_goalie_stats and combined dataset

# %%
game_goalie_stats = game_goalie_stats.drop_duplicates()
game_goalie_stats.columns
# selected: team_id (is there a backup goalie?)
# Out:
# Index(['game_id', 'player_id', 'team_id', 'timeOnIce', 'assists', 'goals',
#        'pim', 'shots', 'saves', 'powerPlaySaves', 'shortHandedSaves',
#        'evenSaves', 'shortHandedShotsAgainst', 'evenShotsAgainst',
#        'powerPlayShotsAgainst', 'decision', 'savePercentage',
#        'powerPlaySavePercentage', 'evenStrengthSavePercentage'],
#       dtype='object')

# %%
game_goalie_stats_subset = game_goalie_stats[['game_id', 'team_id']]
game_goalie_stats_subset = game_goalie_stats_subset.groupby(['game_id', 'team_id'])["team_id"].count().reset_index(name="goalie_count")
game_goalie_stats_subset['goalie_replacement'] = np.where(game_goalie_stats_subset['goalie_count'] == 2, "Yes", "No")
goalie_agg_cols = game_goalie_stats_subset[['game_id', 'team_id', 'goalie_replacement']]

combined = combined.merge(goalie_agg_cols, how='left', left_on=['game_id', 'team_id'], right_on=['game_id', 'team_id'])
print(combined.shape)
combined.head()
# Out:
# (52610, 25)
#       game_id   HoA    won settled_in        head_coach  pim  \
# 0  2016020045  away  False        REG      Dave Hakstol  6.0
# 1  2016020045  home   True        REG  Joel Quenneville  8.0
# 2  2017020812  away   True         OT     Randy Carlyle  6.0
# 3  2017020812  home  False         OT      Phil Housley  8.0
# 4  2015020314  away   True        REG       Patrick Roy  9.0
#
#    powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage startRinkSide  \
# 0                     4.0             2.0                  50.9          left
# 1                     3.0             2.0                  49.1          left
# 2                     3.0             1.0                  43.8         right
# 3                     2.0             1.0                  56.2         right
# 4                     3.0             1.0                  45.7          left
#
#    Shots  Goals  Takeaways  Hits  Blocked Shots  Giveaways  Missed Shots  \
# 0    8.0    0.0        1.0  14.0            3.0        6.0           4.0
# 1    8.0    3.0        3.0   5.0            3.0        7.0           0.0
# 2   11.0    0.0        0.0   4.0            6.0        2.0           6.0
# 3   12.0    1.0        2.0   4.0            8.0        0.0           3.0
# 4    9.0    0.0        3.0   4.0            7.0        7.0           3.0
#
#    Penalities  #Won Faceoffs  team_id    timeOnIce  evenTimeOnIce  \
# 0         1.0           10.0      4.0   990.833333     841.388889
# 1         1.0           12.0     16.0   981.333333     836.777778
# 2         1.0           11.0     24.0  1002.222222     879.611111
# 3         3.0            9.0      7.0   999.222222     888.333333
# 4         2.0            7.0     21.0   986.666667     844.722222
#
#    shortHandedTimeOnIce  powerPlayTimeOnIce goalie_replacement
# 0             55.555556           93.888889                Yes
# 1             75.111111           69.444444                 No
# 2             28.444444           94.166667                 No
# 3             75.333333           35.555556                 No
# 4             53.333333           88.611111                 No

# %% [markdown]
# ### Dealing with timing issue
#
# Assumption: Holding events occur evenly over each period. For the columns below,
# - pim
# - powerPlayOpportunities
# - powerPlayGoals
# - timeOnIce
# - evenTimeOnIce
# - shortHandedTimeOnIce
# - powerPlayTimeOnIce
#
# statistics in these columns will be divided by 3 to have values for just period 1.

# %%
columns = ['pim', 'powerPlayOpportunities', 'powerPlayGoals', 'timeOnIce', 
           'evenTimeOnIce', 'shortHandedTimeOnIce', 'powerPlayTimeOnIce']

for column in columns:
    combined[column] = (combined[column]/3).round(2)

# %%
combined.head()
# Out:
#       game_id   HoA    won settled_in        head_coach   pim  \
# 0  2016020045  away  False        REG      Dave Hakstol  2.00
# 1  2016020045  home   True        REG  Joel Quenneville  2.67
# 2  2017020812  away   True         OT     Randy Carlyle  2.00
# 3  2017020812  home  False         OT      Phil Housley  2.67
# 4  2015020314  away   True        REG       Patrick Roy  3.00
#
#    powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage startRinkSide  \
# 0                    1.33            0.67                  50.9          left
# 1                    1.00            0.67                  49.1          left
# 2                    1.00            0.33                  43.8         right
# 3                    0.67            0.33                  56.2         right
# 4                    1.00            0.33                  45.7          left
#
#    Shots  Goals  Takeaways  Hits  Blocked Shots  Giveaways  Missed Shots  \
# 0    8.0    0.0        1.0  14.0            3.0        6.0           4.0
# 1    8.0    3.0        3.0   5.0            3.0        7.0           0.0
# 2   11.0    0.0        0.0   4.0            6.0        2.0           6.0
# 3   12.0    1.0        2.0   4.0            8.0        0.0           3.0
# 4    9.0    0.0        3.0   4.0            7.0        7.0           3.0
#
#    Penalities  #Won Faceoffs  team_id  timeOnIce  evenTimeOnIce  \
# 0         1.0           10.0      4.0     330.28         280.46
# 1         1.0           12.0     16.0     327.11         278.93
# 2         1.0           11.0     24.0     334.07         293.20
# 3         3.0            9.0      7.0     333.07         296.11
# 4         2.0            7.0     21.0     328.89         281.57
#
#    shortHandedTimeOnIce  powerPlayTimeOnIce goalie_replacement
# 0                 18.52               31.30                Yes
# 1                 25.04               23.15                 No
# 2                  9.48               31.39                 No
# 3                 25.11               11.85                 No
# 4                 17.78               29.54                 No

# %%
combined.columns
# Out:
# Index(['game_id', 'HoA', 'won', 'settled_in', 'head_coach', 'pim',
#        'powerPlayOpportunities', 'powerPlayGoals', 'faceOffWinPercentage',
#        'startRinkSide', 'Shots', 'Goals', 'Takeaways', 'Hits', 'Blocked Shots',
#        'Giveaways', 'Missed Shots', 'Penalities', '#Won Faceoffs', 'team_id',
#        'timeOnIce', 'evenTimeOnIce', 'shortHandedTimeOnIce',
#        'powerPlayTimeOnIce', 'goalie_replacement'],
#       dtype='object')
