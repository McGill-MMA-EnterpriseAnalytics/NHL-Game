# %% [markdown]
# # EDA
# Files:
# - game.csv
# - game_teams_stats.csv
# - game_skater_stats.csv
# - game_goalie_stats.csv
# - player_info.csv

# %%
import pandas as pd
import numpy as np
import copy
import math

pd.set_option('display.max_columns', None)

# %%
data_path = 'nhl_data/'

# %%
games = pd.read_csv(data_path+'game.csv')
print(games.shape)
games.head()
# Out:
# (26305, 15)
#       game_id    season type         date_time_GMT  away_team_id  \
# 0  2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1  2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2  2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3  2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4  2017020586  20172018    R  2017-12-30T03:00:00Z            20
#
#    home_team_id  away_goals  home_goals       outcome home_rink_side_start  \
# 0            16           4           7  home win REG                right
# 1             7           4           3   away win OT                 left
# 2            52           4           1  away win REG                right
# 3            12           1           2  home win REG                right
# 4            24           1           2  home win REG                 left
#
#             venue           venue_link   venue_time_zone_id  \
# 0   United Center  /api/v1/venues/null      America/Chicago
# 1  KeyBank Center  /api/v1/venues/null     America/New_York
# 2      MTS Centre  /api/v1/venues/null     America/Winnipeg
# 3       PNC Arena  /api/v1/venues/null     America/New_York
# 4    Honda Center  /api/v1/venues/null  America/Los_Angeles
#
#    venue_time_zone_offset venue_time_zone_tz
# 0                      -5                CDT
# 1                      -4                EDT
# 2                      -5                CDT
# 3                      -4                EDT
# 4                      -7                PDT

# %%
game_stats = pd.read_csv(data_path+'game_teams_stats.csv')
print(game_stats.shape)
game_stats.head()
# Out:
# (52610, 17)
#       game_id  team_id   HoA    won settled_in        head_coach  goals  \
# 0  2016020045        4  away  False        REG      Dave Hakstol    4.0
# 1  2016020045       16  home   True        REG  Joel Quenneville    7.0
# 2  2017020812       24  away   True         OT     Randy Carlyle    4.0
# 3  2017020812        7  home  False         OT      Phil Housley    3.0
# 4  2015020314       21  away   True        REG       Patrick Roy    4.0
#
#    shots  hits  pim  powerPlayOpportunities  powerPlayGoals  \
# 0   27.0  30.0  6.0                     4.0             2.0
# 1   28.0  20.0  8.0                     3.0             2.0
# 2   34.0  16.0  6.0                     3.0             1.0
# 3   33.0  17.0  8.0                     2.0             1.0
# 4   29.0  17.0  9.0                     3.0             1.0
#
#    faceOffWinPercentage  giveaways  takeaways  blocked startRinkSide
# 0                  50.9       12.0        9.0     11.0          left
# 1                  49.1       16.0        8.0      9.0          left
# 2                  43.8        7.0        4.0     14.0         right
# 3                  56.2        5.0        6.0     14.0         right
# 4                  45.7       13.0        5.0     20.0          left

# %%
game_skater_stats = pd.read_csv(data_path+'game_skater_stats.csv')
print(game_skater_stats.shape)
game_skater_stats.head()
# Out:
# (945830, 22)
#       game_id  player_id  team_id  timeOnIce  assists  goals  shots  hits  \
# 0  2016020045    8468513        4        955        1      0      0   2.0
# 1  2016020045    8476906        4       1396        1      0      4   2.0
# 2  2016020045    8474668        4        915        0      0      1   1.0
# 3  2016020045    8473512        4       1367        3      0      0   0.0
# 4  2016020045    8471762        4        676        0      0      3   2.0
#
#    powerPlayGoals  powerPlayAssists  penaltyMinutes  faceOffWins  \
# 0               0                 0               0            0
# 1               0                 0               2            0
# 2               0                 0               0            0
# 3               0                 2               0           11
# 4               0                 0               0            0
#
#    faceoffTaken  takeaways  giveaways  shortHandedGoals  shortHandedAssists  \
# 0             0        1.0        1.0                 0                   0
# 1             0        1.0        2.0                 0                   0
# 2             0        2.0        0.0                 0                   0
# 3            27        0.0        0.0                 0                   0
# 4             0        0.0        1.0                 0                   0
#
#    blocked  plusMinus  evenTimeOnIce  shortHandedTimeOnIce  powerPlayTimeOnIce
# 0      1.0          1            858                    97                   0
# 1      2.0          0           1177                     0                 219
# 2      0.0         -1            805                     0                 110
# 3      0.0         -1           1083                    19                 265
# 4      0.0         -1            613                    63                   0

# %%
game_goalie_stats = pd.read_csv(data_path+'game_goalie_stats.csv')
print(game_goalie_stats.shape)
game_goalie_stats.head()
# Out:
# (56656, 19)
#       game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 0  2016020045    8473607        4       1504        0      0    0     16
# 1  2016020045    8473461        4       2011        0      0    0     11
# 2  2016020045    8470645       16       3598        0      0    0     27
# 3  2017020812    8468011       24       3696        0      0    0     33
# 4  2017020812    8475215        7       3539        0      0    0     33
#
#    saves  powerPlaySaves  shortHandedSaves  evenSaves  \
# 0     12               1                 0         11
# 1      9               1                 0          8
# 2     23               2                 0         21
# 3     30               1                 2         27
# 4     29               4                 1         24
#
#    shortHandedShotsAgainst  evenShotsAgainst  powerPlayShotsAgainst decision  \
# 0                        0                13                      3      NaN
# 1                        0                10                      1        L
# 2                        0                23                      4        W
# 3                        3                28                      2        W
# 4                        1                27                      5        L
#
#    savePercentage  powerPlaySavePercentage  evenStrengthSavePercentage
# 0       75.000000                33.333333                   84.615385
# 1       81.818182               100.000000                   80.000000
# 2       85.185185                50.000000                   91.304348
# 3       90.909091                50.000000                   96.428571
# 4       87.878788                80.000000                   88.888889

# %%
game_player = pd.read_csv(data_path+'player_info.csv')
print(game_player.shape)
game_player.head()
# Out:
# (3925, 12)
#    player_id firstName      lastName nationality       birthCity  \
# 0    8466148    Marian         Hossa         SVK   Stará Lubovna
# 1    8465058    Michal      Rozsival         CZE          Vlasim
# 2    8476906    Shayne  Gostisbehere         USA  Pembroke Pines
# 3    8466285     Brian      Campbell         CAN       Strathroy
# 4    8470607     Brent      Seabrook         CAN        Richmond
#
#   primaryPosition            birthDate birthStateProvince  height  height_cm  \
# 0              RW  1979-01-12 00:00:00                NaN   6' 1"     185.42
# 1               D  1978-09-03 01:00:00                NaN   6' 1"     185.42
# 2               D  1993-04-20 01:00:00                 FL  5' 11"     180.34
# 3               D  1979-05-23 01:00:00                 ON  5' 10"     177.80
# 4               D  1985-04-20 01:00:00                 BC   6' 3"     190.50
#
#    weight shootsCatches
# 0   207.0             L
# 1   210.0             R
# 2   180.0             L
# 3   192.0             L
# 4   220.0             R

# %%
game_plays = pd.read_csv(data_path+'game_plays.csv')
print(game_plays.shape)
game_plays.head()
# Out:
# (5050529, 18)
#         play_id     game_id  team_id_for  team_id_against           event  \
# 0  2016020045_1  2016020045          NaN              NaN  Game Scheduled
# 1  2016020045_2  2016020045          NaN              NaN    Period Ready
# 2  2016020045_3  2016020045          NaN              NaN    Period Start
# 3  2016020045_4  2016020045         16.0              4.0         Faceoff
# 4  2016020045_5  2016020045         16.0              4.0            Shot
#
#   secondaryType     x    y  period periodType  periodTime  \
# 0           NaN   NaN  NaN       1    REGULAR           0
# 1           NaN   NaN  NaN       1    REGULAR           0
# 2           NaN   NaN  NaN       1    REGULAR           0
# 3           NaN   0.0  0.0       1    REGULAR           0
# 4    Wrist Shot -71.0  9.0       1    REGULAR          54
#
#    periodTimeRemaining             dateTime  goals_away  goals_home  \
# 0               1200.0  2016-10-18 23:40:58           0           0
# 1               1200.0  2016-10-19 01:35:28           0           0
# 2               1200.0  2016-10-19 01:40:50           0           0
# 3               1200.0  2016-10-19 01:40:50           0           0
# 4               1146.0  2016-10-19 01:41:44           0           0
#
#                                          description  st_x  st_y
# 0                                     Game Scheduled   NaN   NaN
# 1                                       Period Ready   NaN   NaN
# 2                                       Period Start   NaN   NaN
# 3   Jonathan Toews faceoff won against Claude Giroux   0.0   0.0
# 4  Artem Anisimov Wrist Shot saved by Michal Neuv...  71.0  -9.0

# %% [markdown]
# ## Merge other data
# - drop duplicates
# - append columns to the 'game_stats'

# %% [markdown]
# ### Merge games and game_plays

# %%
games = games.drop_duplicates()
games.columns
games_cols = games[['game_id', 'type', 'date_time_GMT', 'home_rink_side_start', 'venue', 'venue_time_zone_id', 'venue_time_zone_offset', 'venue_time_zone_tz']]
# selected columns: 'type', 'date_time_GMT', 'home_rink_side_start', 'venue', 'venue_time_zone_id', 
# 'venue_time_zone_offset', 'venue_time_zone_tz'

# %%
game_plays = game_plays.drop_duplicates()
game_plays.columns
game_plays = game_plays[['play_id', 'game_id',
                        'period', 'periodType', 'periodTime','periodTimeRemaining']]

# %%
# game_combine = games_cols.merge(game_plays, how='left', left_on='game_id', right_on='game_id')
game_combine.head(200)
# Out:
#         game_id type         date_time_GMT home_rink_side_start  \
# 0    2016020045    R  2016-10-19T00:30:00Z                right
# 1    2016020045    R  2016-10-19T00:30:00Z                right
# 2    2016020045    R  2016-10-19T00:30:00Z                right
# 3    2016020045    R  2016-10-19T00:30:00Z                right
# 4    2016020045    R  2016-10-19T00:30:00Z                right
# ..          ...  ...                   ...                  ...
# 195  2016020045    R  2016-10-19T00:30:00Z                right
# 196  2016020045    R  2016-10-19T00:30:00Z                right
# 197  2016020045    R  2016-10-19T00:30:00Z                right
# 198  2016020045    R  2016-10-19T00:30:00Z                right
# 199  2016020045    R  2016-10-19T00:30:00Z                right
#
#              venue venue_time_zone_id  venue_time_zone_offset  \
# 0    United Center    America/Chicago                      -5
# 1    United Center    America/Chicago                      -5
# 2    United Center    America/Chicago                      -5
# 3    United Center    America/Chicago                      -5
# 4    United Center    America/Chicago                      -5
# ..             ...                ...                     ...
# 195  United Center    America/Chicago                      -5
# 196  United Center    America/Chicago                      -5
# 197  United Center    America/Chicago                      -5
# 198  United Center    America/Chicago                      -5
# 199  United Center    America/Chicago                      -5
#
#     venue_time_zone_tz         play_id  period periodType  periodTime  \
# 0                  CDT    2016020045_1     1.0    REGULAR         0.0
# 1                  CDT    2016020045_2     1.0    REGULAR         0.0
# 2                  CDT    2016020045_3     1.0    REGULAR         0.0
# 3                  CDT    2016020045_4     1.0    REGULAR         0.0
# 4                  CDT    2016020045_5     1.0    REGULAR        54.0
# ..                 ...             ...     ...        ...         ...
# 195                CDT  2016020045_196     2.0    REGULAR      1101.0
# 196                CDT  2016020045_197     2.0    REGULAR      1103.0
# 197                CDT  2016020045_198     2.0    REGULAR      1103.0
# 198                CDT  2016020045_199     2.0    REGULAR      1112.0
# 199                CDT  2016020045_200     2.0    REGULAR      1124.0
#
#      periodTimeRemaining
# 0                 1200.0
# 1                 1200.0
# 2                 1200.0
# 3                 1200.0
# 4                 1146.0
# ..                   ...
# 195                 99.0
# 196                 97.0
# 197                 97.0
# 198                 88.0
# 199                 76.0
#
# [200 rows x 13 columns]

# %% [markdown]
# ### Merge games and game_stats

# %%
game_stats.drop_duplicates()
combined = game_stats.copy()
combined = combined.merge(game_combine, how='left', left_on='game_id', right_on='game_id')
print(combined.shape)
combined.head()
# Out:
# (10101884, 29)
#       game_id  team_id   HoA    won settled_in    head_coach  goals  shots  \
# 0  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 1  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 2  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 3  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 4  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
#
#    hits  pim  powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage  \
# 0  30.0  6.0                     4.0             2.0                  50.9
# 1  30.0  6.0                     4.0             2.0                  50.9
# 2  30.0  6.0                     4.0             2.0                  50.9
# 3  30.0  6.0                     4.0             2.0                  50.9
# 4  30.0  6.0                     4.0             2.0                  50.9
#
#    giveaways  takeaways  blocked startRinkSide type         date_time_GMT  \
# 0       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 1       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 2       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 3       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 4       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
#
#   home_rink_side_start          venue venue_time_zone_id  \
# 0                right  United Center    America/Chicago
# 1                right  United Center    America/Chicago
# 2                right  United Center    America/Chicago
# 3                right  United Center    America/Chicago
# 4                right  United Center    America/Chicago
#
#    venue_time_zone_offset venue_time_zone_tz       play_id  period periodType  \
# 0                      -5                CDT  2016020045_1     1.0    REGULAR
# 1                      -5                CDT  2016020045_2     1.0    REGULAR
# 2                      -5                CDT  2016020045_3     1.0    REGULAR
# 3                      -5                CDT  2016020045_4     1.0    REGULAR
# 4                      -5                CDT  2016020045_5     1.0    REGULAR
#
#    periodTime  periodTimeRemaining
# 0         0.0               1200.0
# 1         0.0               1200.0
# 2         0.0               1200.0
# 3         0.0               1200.0
# 4        54.0               1146.0

# %%
combined.columns
# Out:
# Index(['game_id', 'team_id', 'HoA', 'won', 'settled_in', 'head_coach', 'goals',
#        'shots', 'hits', 'pim', 'powerPlayOpportunities', 'powerPlayGoals',
#        'faceOffWinPercentage', 'giveaways', 'takeaways', 'blocked',
#        'startRinkSide', 'type', 'date_time_GMT', 'home_rink_side_start',
#        'venue', 'venue_time_zone_id', 'venue_time_zone_offset',
#        'venue_time_zone_tz', 'play_id', 'period', 'periodType', 'periodTime',
#        'periodTimeRemaining'],
#       dtype='object')

# %% [markdown]
# ### Merge game_skater_stats and game_stats

# %%
game_skater_stats = game_skater_stats.drop_duplicates()
game_skater_stats.columns
# selected columns: timeOnIce, evenTimeOnIce, shortHandedTimeOnIce, powerPlayTimeOnIce
# Out:
# Index(['game_id', 'player_id', 'team_id', 'timeOnIce', 'assists', 'goals',
#        'shots', 'hits', 'powerPlayGoals', 'powerPlayAssists', 'penaltyMinutes',
#        'faceOffWins', 'faceoffTaken', 'takeaways', 'giveaways',
#        'shortHandedGoals', 'shortHandedAssists', 'blocked', 'plusMinus',
#        'evenTimeOnIce', 'shortHandedTimeOnIce', 'powerPlayTimeOnIce'],
#       dtype='object')

# %%
skater_agg_cols = game_skater_stats.groupby(['game_id', 'team_id'], as_index=False)[['timeOnIce', 'evenTimeOnIce', 'shortHandedTimeOnIce', 'powerPlayTimeOnIce']].mean()
combined = combined.merge(skater_agg_cols, how='left', left_on=['game_id', 'team_id'], right_on=['game_id', 'team_id'])
print(combined.shape)
combined.head()
# Out:
# (10101884, 33)
#       game_id  team_id   HoA    won settled_in    head_coach  goals  shots  \
# 0  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 1  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 2  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 3  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 4  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
#
#    hits  pim  powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage  \
# 0  30.0  6.0                     4.0             2.0                  50.9
# 1  30.0  6.0                     4.0             2.0                  50.9
# 2  30.0  6.0                     4.0             2.0                  50.9
# 3  30.0  6.0                     4.0             2.0                  50.9
# 4  30.0  6.0                     4.0             2.0                  50.9
#
#    giveaways  takeaways  blocked startRinkSide type         date_time_GMT  \
# 0       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 1       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 2       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 3       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 4       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
#
#   home_rink_side_start          venue venue_time_zone_id  \
# 0                right  United Center    America/Chicago
# 1                right  United Center    America/Chicago
# 2                right  United Center    America/Chicago
# 3                right  United Center    America/Chicago
# 4                right  United Center    America/Chicago
#
#    venue_time_zone_offset venue_time_zone_tz       play_id  period periodType  \
# 0                      -5                CDT  2016020045_1     1.0    REGULAR
# 1                      -5                CDT  2016020045_2     1.0    REGULAR
# 2                      -5                CDT  2016020045_3     1.0    REGULAR
# 3                      -5                CDT  2016020045_4     1.0    REGULAR
# 4                      -5                CDT  2016020045_5     1.0    REGULAR
#
#    periodTime  periodTimeRemaining   timeOnIce  evenTimeOnIce  \
# 0         0.0               1200.0  990.833333     841.388889
# 1         0.0               1200.0  990.833333     841.388889
# 2         0.0               1200.0  990.833333     841.388889
# 3         0.0               1200.0  990.833333     841.388889
# 4        54.0               1146.0  990.833333     841.388889
#
#    shortHandedTimeOnIce  powerPlayTimeOnIce
# 0             55.555556           93.888889
# 1             55.555556           93.888889
# 2             55.555556           93.888889
# 3             55.555556           93.888889
# 4             55.555556           93.888889

# %%
combined.columns
# Out:
# Index(['game_id', 'team_id', 'HoA', 'won', 'settled_in', 'head_coach', 'goals',
#        'shots', 'hits', 'pim', 'powerPlayOpportunities', 'powerPlayGoals',
#        'faceOffWinPercentage', 'giveaways', 'takeaways', 'blocked',
#        'startRinkSide', 'type', 'date_time_GMT', 'home_rink_side_start',
#        'venue', 'venue_time_zone_id', 'venue_time_zone_offset',
#        'venue_time_zone_tz', 'play_id', 'period', 'periodType', 'periodTime',
#        'periodTimeRemaining', 'timeOnIce', 'evenTimeOnIce',
#        'shortHandedTimeOnIce', 'powerPlayTimeOnIce'],
#       dtype='object')

# %% [markdown]
# ### Merge game_goalie_stats and game_stats

# %%
game_goalie_stats = game_goalie_stats.drop_duplicates()
game_goalie_stats.columns
# selected: team_id (is there a backup goalie?)
# Out:
# Index(['game_id', 'player_id', 'team_id', 'timeOnIce', 'assists', 'goals',
#        'pim', 'shots', 'saves', 'powerPlaySaves', 'shortHandedSaves',
#        'evenSaves', 'shortHandedShotsAgainst', 'evenShotsAgainst',
#        'powerPlayShotsAgainst', 'decision', 'savePercentage',
#        'powerPlaySavePercentage', 'evenStrengthSavePercentage'],
#       dtype='object')

# %%
game_goalie_stats_subset = game_goalie_stats[['game_id', 'team_id']]
game_goalie_stats_subset = game_goalie_stats_subset.groupby(['game_id', 'team_id'])["team_id"].count().reset_index(name="goalie_count")
game_goalie_stats_subset['goalie_replacement'] = np.where(game_goalie_stats_subset['goalie_count'] == 2, "Yes", "No")
goalie_agg_cols = game_goalie_stats_subset[['game_id', 'team_id', 'goalie_replacement']]

combined = combined.merge(goalie_agg_cols, how='left', left_on=['game_id', 'team_id'], right_on=['game_id', 'team_id'])
print(combined.shape)
combined.head()
# Out:
# (10101884, 34)
#       game_id  team_id   HoA    won settled_in    head_coach  goals  shots  \
# 0  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 1  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 2  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 3  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
# 4  2016020045        4  away  False        REG  Dave Hakstol    4.0   27.0
#
#    hits  pim  powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage  \
# 0  30.0  6.0                     4.0             2.0                  50.9
# 1  30.0  6.0                     4.0             2.0                  50.9
# 2  30.0  6.0                     4.0             2.0                  50.9
# 3  30.0  6.0                     4.0             2.0                  50.9
# 4  30.0  6.0                     4.0             2.0                  50.9
#
#    giveaways  takeaways  blocked startRinkSide type         date_time_GMT  \
# 0       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 1       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 2       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 3       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
# 4       12.0        9.0     11.0          left    R  2016-10-19T00:30:00Z
#
#   home_rink_side_start          venue venue_time_zone_id  \
# 0                right  United Center    America/Chicago
# 1                right  United Center    America/Chicago
# 2                right  United Center    America/Chicago
# 3                right  United Center    America/Chicago
# 4                right  United Center    America/Chicago
#
#    venue_time_zone_offset venue_time_zone_tz       play_id  period periodType  \
# 0                      -5                CDT  2016020045_1     1.0    REGULAR
# 1                      -5                CDT  2016020045_2     1.0    REGULAR
# 2                      -5                CDT  2016020045_3     1.0    REGULAR
# 3                      -5                CDT  2016020045_4     1.0    REGULAR
# 4                      -5                CDT  2016020045_5     1.0    REGULAR
#
#    periodTime  periodTimeRemaining   timeOnIce  evenTimeOnIce  \
# 0         0.0               1200.0  990.833333     841.388889
# 1         0.0               1200.0  990.833333     841.388889
# 2         0.0               1200.0  990.833333     841.388889
# 3         0.0               1200.0  990.833333     841.388889
# 4        54.0               1146.0  990.833333     841.388889
#
#    shortHandedTimeOnIce  powerPlayTimeOnIce goalie_replacement
# 0             55.555556           93.888889                Yes
# 1             55.555556           93.888889                Yes
# 2             55.555556           93.888889                Yes
# 3             55.555556           93.888889                Yes
# 4             55.555556           93.888889                Yes

# %%
combined.columns
# Out:
# Index(['game_id', 'team_id', 'HoA', 'won', 'settled_in', 'head_coach', 'goals',
#        'shots', 'hits', 'pim', 'powerPlayOpportunities', 'powerPlayGoals',
#        'faceOffWinPercentage', 'giveaways', 'takeaways', 'blocked',
#        'startRinkSide', 'type', 'date_time_GMT', 'home_rink_side_start',
#        'venue', 'venue_time_zone_id', 'venue_time_zone_offset',
#        'venue_time_zone_tz', 'play_id', 'period', 'periodType', 'periodTime',
#        'periodTimeRemaining', 'timeOnIce', 'evenTimeOnIce',
#        'shortHandedTimeOnIce', 'powerPlayTimeOnIce', 'goalie_replacement'],
#       dtype='object')
